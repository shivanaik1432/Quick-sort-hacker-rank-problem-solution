# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'quickSort' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def quickSort(arr):
    left=[]
    right=[]
    equal=[]
    for i in arr:
        if arr[0] == i:
            equal.append(i)
        elif arr[0] > i:
            right.append(i)
        elif arr[0] < i:
            left.append(i)
    lis=right+equal+left
    return lis
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    result = quickSort(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# ![quicksort1.png](attachment:quicksort1.png)

# %% [markdown]
# ![quicksort2.png](attachment:quicksort2.png)

# %% [markdown]
# ![quicksort4.png](attachment:quicksort4.png)
